# %%
import pandas as pd
import numpy as np
import os
import sqlalchemy
from pymongo import MongoClient
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
import datetime as dt
from pprint import pprint

# %%
pd.options.display.max_colwidth = 200
file1 = pd.read_csv("Talitta-Test1.csv")
file1
# Out:
#           Timestamp  From Bank From Account  To Bank To Account  \
# 0  2022/09/01 06:13          2    800042CB0        1  800059440
# 1  2022/09/01 08:01          2    800042CB0     9129  8087F7F80
# 2  2022/09/01 08:21         70    100428A51       15  813774941
# 3  2022/09/01 08:26         70    100428A51      225  813B5C5E1
# 4  2022/09/01 08:12        220    813A831A1       15  813A83061
# 5  2022/09/01 06:02          2    800042CB0        1  800059440
# 6  2022/09/01 08:06        220    813A831A1       15  813A83061
# 7  2022/09/01 08:21         70    100428A51      225  813B5C5E1
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0       211.750000          US Dollar   211.750000        US Dollar
# 1      3177.950000          US Dollar  3177.950000        US Dollar
# 2         0.624968            Bitcoin     0.624968          Bitcoin
# 3         0.499435            Bitcoin     0.499435          Bitcoin
# 4         0.089057            Bitcoin     0.089057          Bitcoin
# 5       649.400000          US Dollar   649.400000        US Dollar
# 6         2.040830            Bitcoin     2.040830          Bitcoin
# 7         0.053615            Bitcoin     0.053615          Bitcoin
#
#   Payment Format  Is Laundering
# 0         Cheque              0
# 1         Cheque              0
# 2        Bitcoin              0
# 3        Bitcoin              0
# 4        Bitcoin              0
# 5            ACH              0
# 6        Bitcoin              0
# 7        Bitcoin              0

# %%
sort = file1.sort_values(['From Bank','From Account'])
sort
# Out:
#           Timestamp  From Bank From Account  To Bank To Account  \
# 0  2022/09/01 06:13          2    800042CB0        1  800059440
# 1  2022/09/01 08:01          2    800042CB0     9129  8087F7F80
# 5  2022/09/01 06:02          2    800042CB0        1  800059440
# 2  2022/09/01 08:21         70    100428A51       15  813774941
# 3  2022/09/01 08:26         70    100428A51      225  813B5C5E1
# 7  2022/09/01 08:21         70    100428A51      225  813B5C5E1
# 4  2022/09/01 08:12        220    813A831A1       15  813A83061
# 6  2022/09/01 08:06        220    813A831A1       15  813A83061
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0       211.750000          US Dollar   211.750000        US Dollar
# 1      3177.950000          US Dollar  3177.950000        US Dollar
# 5       649.400000          US Dollar   649.400000        US Dollar
# 2         0.624968            Bitcoin     0.624968          Bitcoin
# 3         0.499435            Bitcoin     0.499435          Bitcoin
# 7         0.053615            Bitcoin     0.053615          Bitcoin
# 4         0.089057            Bitcoin     0.089057          Bitcoin
# 6         2.040830            Bitcoin     2.040830          Bitcoin
#
#   Payment Format  Is Laundering
# 0         Cheque              0
# 1         Cheque              0
# 5            ACH              0
# 2        Bitcoin              0
# 3        Bitcoin              0
# 7        Bitcoin              0
# 4        Bitcoin              0
# 6        Bitcoin              0

# %%
x =
# Out:
# From Bank
# From Account
